# %%
from base64 import encode
import os
import pandas as pd
import numpy as np
from typing import Callable, List
from tqdm import tqdm
from scipy.spatial import distance

# %%
word2vecpath = '../word2vec/W2V_150.txt'
ant_sym_path = '../antonym-synonym set'
visimpath = '../datasets/ViSim-400'
viconpath = '../datasets/ViCon-400'

# %%
words = []
vecs = []

dim = None
n_vocab = None

with open(word2vecpath, encoding='utf8') as f:
    for line in tqdm(f, f"loading {word2vecpath} to variables"):
        if not n_vocab:
            n_vocab = int(line)
        elif not dim:
            dim = int(line)
        else:
            line = line.replace('\n', '')
            words.append(line.split('  ')[0])
            vecs.append([float(i) for i in line.split('  ')[1].split()])
vecs = np.array(vecs)


def word2vec(a: str) -> np.array:
    try:
        idx = words.index(a)
        return vecs[idx]
    except:
        return np.zeros(dim)


def cosine(a: np.array, b: np.array) -> float:
    a = a / np.linalg.norm(a) if np.linalg.norm(a) != 0 else a
    b = b / np.linalg.norm(b) if np.linalg.norm(b) != 0 else b
    return a.dot(b)

#  Dot	Product Distance, Euclidean Distance, Dice Distance, Jaccard Distance.


def dot(a: np.array, b: np.array) -> float:
    return a.dot(b)


def euclid(a: np.array, b: np.array) -> float:
    return np.linalg.norm(a - b)


def dice(a: np.array, b: np.array) -> float:
    return distance.dice(a, b)


def jaccard(a: np.array, b: np.array) -> float:
    return distance.jaccard(a, b, w=None)


def sim(row, sim_f=cosine):
    vec1 = word2vec(row.iloc[0])
    vec2 = word2vec(row.iloc[1])

    return sim_f(vec1, vec2)


def topsimilar(
        w: str,
        vocab: List[str] = words,
        encoder: Callable = word2vec,
        distance_by: Callable = cosine,
        n: int = 5) -> list:
    input_encode = encoder(w)
    vocab_sim = [
        (other, distance_by(input_encode, encoder(other)))
        for other in tqdm(vocab, "Scanning vocab")
    ]
    vocab_sim.sort(key=lambda x: x[1], reverse=True)
    return vocab_sim[:n]
# Out:
# loading ../word2vec/W2V_150.txt to variables: 77023it [00:04, 18403.08it/s]

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder(handle_unknown='ignore', sparse=False)

sim_pairs = pd.read_csv(visimpath + '/Visim-400.txt', sep="\t")

noun_pairs = pd.read_csv(viconpath + '/400_verb_pairs.txt', sep="\t")
verb_pairs = pd.read_csv(viconpath + '/400_verb_pairs.txt', sep="\t")
adj_pairs = pd.read_csv(viconpath + '/600_adj_pairs.txt', sep="\t")

dataset = pd.concat([noun_pairs, verb_pairs, adj_pairs])[
    ['Word1', 'Word2', 'Relation']]


def flatten(row):
    vec1 = word2vec(row.iloc[0])
    vec2 = word2vec(row.iloc[1])

    return np.array([vec1, vec2], dtype='float32')


x = np.array([i for i in dataset.apply(flatten, axis=1)])
y = enc.fit_transform(dataset['Relation'].values.reshape(-1, 1))

# %%
ant_pairs = pd.read_csv(ant_sym_path + '/Antonym_vietnamese.txt',
                        delim_whitespace=True, header=None, names=['Word1', 'Word2'])
syn_pairs = pd.read_csv(ant_sym_path + '/Synonym_vietnamese.txt',
                        delim_whitespace=True, header=None, names=['Word1', 'Word2'])

# %%
ant_word_1 = []
ant_word_2 = []

with open(ant_sym_path + '/Antonym_vietnamese.txt', encoding='utf8') as file:
    for line in file:
        line = line.replace('\n', '').split(' ')
        ant_word_1.append(line[0])
        ant_word_2.append(line[1])

# %%
syn_word_1 = []
syn_word_2 = []

with open(ant_sym_path + '/Synonym_vietnamese.txt', encoding='utf8') as file:
    for line in file:
        line = line.replace('\n', '').split(' ')
        syn_word_1.append(line[0])
        syn_word_2.append(line[1])

# %%
def get_synonym(word):
    if word in syn_word_1:
        return syn_word_2[syn_word_1.index(word)]
    if word in syn_word_2:
        return syn_word_1[syn_word_2.index(word)]
    else:
        return None

def get_antonym(word):
    if word in ant_word_1:
        return ant_word_2[ant_word_1.index(word)]
    if word in ant_word_2:
        return ant_word_1[ant_word_2.index(word)]
    else:
        return None

# %%
def get_syn_have_vec(word):
    scanned_syn = [word]
    syn_have_vec = False

    while word is not None:
        word = get_synonym(word)
        if word in scanned_syn:
            break
        else:
            scanned_syn.append(word)

        if np.any(word2vec(word)):
            syn_have_vec = True
            break

    return syn_have_vec, word2vec(word)

# %%
def vec_estimate(word):
    syn_have_vec, syn_vec = get_syn_have_vec(word)

    if syn_have_vec == False:
        return np.zeros(dim)
    
    ant_1 = get_antonym(word)
    while not np.any(word2vec(ant_1)):
        ant_1 = get_synonym(ant_1)

    if not np.any(word2vec(ant_1)):
        return np.zeros(dim)

    ant_2 = get_synonym(ant_1)
    while not np.any(word2vec(ant_2)):
        ant_2 = get_synonym(ant_2)

    if not np.any(word2vec(ant_2)):
        return np.zeros(dim)

    return syn_vec + word2vec(ant_1) - word2vec(ant_2)

# %% [markdown]
# # Task 1

# %%
distances = [('cosine', cosine)]
for name, function in distances:
    sim_pairs[f'sim-{name}'] = sim_pairs.apply(sim, axis=1, sim_f=function)
print(sim_pairs.to_string)
# Out:
#                    Word1                Word2 POS  Sim1  Sim2   STD  sim-cosine
# 0                   biến                 ngập   V  3.13  5.22  0.72   -0.004912
# 1            nhà_thi_đấu                  nhà   N  3.07  5.12  1.18    0.082523
# 2                   động                 tĩnh   V  0.60  1.00  0.95    0.277086
# 3                 khuyết                   ưu   N  0.20  0.33  0.40    0.176799
# 4                cõi_tục               cõi_âm   N  0.60  1.00  0.95    0.000000
# 5               thủ_pháp            biện_pháp   N  4.13  6.88  1.26    0.402366
# 6              kết_duyên            thành_hôn   V  5.27  8.78  1.06    0.463008
# 7               cấp_tiến              bảo_thủ   A  0.87  1.45  1.15    0.256947
# 8               nước_lớn            nguy_hiểm   N  1.07  1.78  1.12    0.185192
# 9                    hoa                  nhị   N  2.27  3.78  0.93    0.223070
# 10               bất_lợi            thuận_lợi   N  0.33  0.55  0.79    0.534891
# 11               phân_ly              sum_họp   V  0.47  0.78  1.09    0.077701
# 12               nói_lắp              nói_móc   V  3.53  5.88  0.81    0.000000
# 13                vây_ép            phong_toả   V  3.40  5.67  0.95    0.000000
# 14             diễu_hành            tuần_hành   V  4.53  7.55  1.15    0.643884
# 15              cao_trào           thoái_trào   N  0.53  0.88  0.88    0.361033
# 16                 thịnh                  suy   V  0.67  1.12  1.14    0.059602
# 17               con_voi                  ngà   N  1.60  2.67  1.08    0.238955
# 18              cá_chuối               cá_quả   N  4.13  6.88  1.31    0.166474
# 19            đổ_bê_tông             biếu_xén   V  0.33  0.55  0.60   -0.172840
# 20                con_đẻ             con_ruột   N  5.33  8.88  1.07    0.641789
# 21              uỷ_nhiệm            phân_công   V  4.33  7.22  1.40    0.287535
# 22              bay_lượn          chuyển_động   V  3.93  6.55  1.18    0.388197
# 23              khêu_gợi             khơi_gợi   V  4.60  7.67  0.80    0.255965
# 24            thăng_bằng             cân_bằng   V  3.53  5.88  1.20    0.480432
# 25              chọn_lựa           tuyển_chọn   N  4.33  7.22  1.19    0.472426
# 26                có_ích              hữu_ích   A  5.67  9.45  0.70    0.662409
# 27              cứng_rắn             nhỏ_nhắn   A  0.47  0.78  0.96    0.225233
# 28             bội_nghĩa              biết_ơn   V  0.40  0.67  0.80    0.000000
# 29                lỗ_đen               hố_đen   N  3.33  5.55  1.14    0.734068
# 30                   vùi                 đóng   V  1.47  2.45  1.41   -0.013610
# 31             tính_tình             tính_khí   N  3.40  5.67  0.80    0.687825
# 32                mục_sư              giáo_sĩ   N  4.00  6.67  0.97    0.596404
# 33             cộng_đồng              dân_tộc   N  3.53  5.88  1.02    0.375444
# 34                    rớ                   sờ   V  5.20  8.67  0.75    0.385614
# 35               trả_đũa              đền_đáp   N  3.13  5.22  1.09    0.233056
# 36               tay_cầm             phân_đạm   N  0.47  0.78  1.02   -0.030257
# 37               liên_hệ           nguỵ_trang   V  0.07  0.12  0.25    0.092398
# 38              mới_tinh            mới_toanh   A  5.73  9.55  0.77    0.481290
# 39               cột_trụ                   bệ   N  2.13  3.55  0.81    0.443029
# 40               họp_mặt                 tiệc   N  3.93  6.55  0.85    0.427640
# 41               lộn_xộn             gọn_gàng   A  0.40  0.67  0.61    0.343537
# 42              chủ_động             thụ_động   V  0.53  0.88  0.88    0.477754
# 43                  vali              tay_cầm   N  1.47  2.45  0.88    0.165983
# 44              đơn_tiết               đơn_âm   A  4.80  8.00  0.83    0.000000
# 45               ghen_tị            ghen_ghét   V  4.60  7.67  1.14    0.351880
# 46           ngả_nghiêng             sờn_lòng   V  3.00  5.00  1.10    0.000000
# 47          ngôn_ngữ_học             khoa_học   N  3.67  6.12  1.40    0.537251
# 48                   vẹo               vẹo_vọ   A  4.93  8.22  0.93    0.000000
# 49               thu_gom             tiếp_sức   V  0.73  1.22  0.77    0.170182
# 50             quy_trình             sáng_tác   N  3.20  5.33  0.83   -0.095678
# 51             thành_thị            thị_thành   N  5.93  9.88  0.25    0.405811
# 52             nhảy_nhót                nhích   V  3.60  6.00  1.14    0.177007
# 53                ly_tâm            hướng_tâm   V  0.73  1.22  0.85    0.092953
# 54                  cống            đường_ống   N  4.40  7.33  1.08    0.656180
# 55                   còm             nhỏ_nhoi   A  3.80  6.33  1.22    0.159148
# 56             bánh_răng                 răng   N  1.87  3.12  0.81    0.257400
# 57              nao_núng            kiên_định   V  0.27  0.45  0.57    0.251818
# 58              bằng_hữu              bầu_bạn   N  4.27  7.12  1.24    0.313873
# 59                  thân                 lưng   N  2.13  3.55  0.88    0.307931
# 60               bút_chì                   lô   N  0.00  0.00  0.00    0.141503
# 61                  cổng               ổ_khoá   N  2.27  3.78  0.77    0.353678
# 62                dị_bản              đĩa_bay   N  0.47  0.78  0.88    0.166300
# 63           nguây_nguẩy          ngúng_nguẩy   V  4.87  8.12  1.20    0.000000
# 64             biên_nhận            ứng_chiến   V  0.60  1.00  0.80    0.000000
# 65              truy_cập            thâm_nhập   V  4.27  7.12  0.77    0.490286
# 66              chỉ_định               hạ_bút   V  0.27  0.45  0.57    0.000000
# 67                    âm            nguy_hiểm   N  0.33  0.55  0.60    0.090242
# 68            thăng_trầm             khô_kiệt   A  0.33  0.55  0.70   -0.009955
# 69              thay_thế             biến_đổi   N  4.13  6.88  1.02    0.183058
# 70              ban_công              lan_can   N  2.33  3.88  0.79    0.550134
# 71                  dưới                 trên   N  0.40  0.67  0.71    0.210099
# 72              kháng_cự             phản_đối   V  4.00  6.67  0.97    0.054426
# 73                   cầm                rờ_mó   V  3.73  6.22  1.12    0.000000
# 74                    vế               vai_vế   N  4.27  7.12  0.85    0.194592
# 75             vắng_lặng                ồn_ào   A  0.33  0.55  0.70    0.553082
# 76            xót_thương             đau_lòng   V  5.27  8.78  0.77    0.539622
# 77              găng_tay              quần_áo   N  3.13  5.22  0.88    0.444777
# 78               lộp_bộp              lộp_độp   A  5.13  8.55  0.81    0.000000
# 79         sinh_vật_cảnh             đồng_dao   N  0.07  0.12  0.25    0.182529
# 80                   lặn                  mọc   V  0.33  0.55  0.70    0.188433
# 81               bồ_bịch            nhân_tình   N  5.27  8.78  0.85    0.430568
# 82            bằng_chứng             chứng_cứ   N  3.33  5.55  0.70    0.728348
# 83                hạ_màn               mở_màn   V  0.33  0.55  0.70    0.481283
# 84               ca_tụng             đoàn_kết   V  2.67  4.45  0.70    0.061654
# 85                  ngày                  đêm   N  0.33  0.55  0.70    0.501829
# 86               lan_can                  rào   N  2.80  4.67  0.75    0.497195
# 87               trở_lại            đảo_ngược   V  3.00  5.00  0.73    0.264055
# 88              nhạc_nhẹ             tiểu_học   N  0.00  0.00  0.00   -0.008235
# 89                 tự_do             đức_tính   N  1.00  1.67  1.03    0.001607
# 90              hợp_nhất             liên_kết   N  3.53  5.88  1.09    0.338174
# 91             hoàng_tộc            hoàng_gia   N  5.00  8.33  0.82    0.433464
# 92               đầu_mối                  chỗ   N  3.07  5.12  1.06    0.164351
# 93            tinh_luyện             hoá_lỏng   V  2.93  4.88  0.68    0.348911
# 94               bí_hiểm               bí_mật   N  4.40  7.33  1.02    0.287645
# 95            chung_tình              phụ_bạc   V  0.33  0.55  0.60    0.399295
# 96               bàn_cãi             cân_nhắc   V  3.93  6.55  1.12    0.277069
# 97              nhảy_cao              ném_đĩa   N  3.20  5.33  0.75    0.472796
# 98              bánh_hỏi             bánh_giò   N  3.33  5.55  0.70    0.000000
# 99          tiếng_chuông             âm_thanh   N  2.87  4.78  0.72    0.380699
# 100             tha_thẩn             thơ_thẩn   A  4.87  8.12  0.88    0.652056
# 101             phôi_bào               tế_bào   N  4.13  6.88  1.15    0.000000
# 102               thuyền             bánh_lái   N  2.33  3.88  0.87    0.395752
# 103                  nấp                 hiện   V  0.20  0.33  0.40    0.037029
# 104                  cất                 giấu   V  4.87  8.12  1.15    0.425594
# 105                   âm                  gốc   N  1.47  2.45  1.02    0.300258
# 106                  đặt             thả_lỏng   V  2.07  3.45  1.12    0.117888
# 107           chỉnh_hình             tiểu_học   N  0.13  0.22  0.34    0.119303
# 108                  tẩy                  cạn   V  2.07  3.45  1.00    0.141839
# 109            cây_trồng              đĩa_bay   N  0.07  0.12  0.25    0.100014
# 110           chỉnh_hình                luồng   N  0.53  0.88  1.02   -0.173409
# 111          màng_tế_bào        bảng_tổng_sắp   N  0.13  0.22  0.34   -0.019664
# 112           ngót_nghét               xấp_xỉ   A  5.33  8.88  0.60    0.433085
# 113            biến_động              cố_định   V  0.27  0.45  0.57    0.238897
# 114          khuyết_điểm              ưu_điểm   N  0.27  0.45  0.57    0.392474
# 115            nhạo_báng            khiếm_nhã   N  4.47  7.45  1.02    0.479190
# 116                  hại                  lợi   N  0.13  0.22  0.34    0.231003
# 117              bướu_cổ             bệnh_tật   N  3.07  5.12  1.06    0.394998
# 118            cây_thuốc          cây_hoa_màu   N  3.27  5.45  1.24    0.364958
# 119             tinh_lọc             tinh_chế   V  4.93  8.22  0.85    0.527015
# 120             tăm_dạng            tung_tích   N  4.53  7.55  0.72    0.000000
# 121              bức_bối           nguỵ_trang   V  0.60  1.00  0.95   -0.045686
# 122             thân_thể                  đầu   N  2.53  4.22  0.88   -0.049440
# 123             thừa_thế              hằn_học   V  0.87  1.45  1.26    0.000000
# 124            quỷ_quyệt            xảo_quyệt   A  4.87  8.12  0.72    0.634807
# 125            hoang_phí              hà_tiện   V  0.33  0.55  0.60    0.503644
# 126             cóp_nhặt              để_dành   V  4.40  7.33  1.08    0.150024
# 127                  may                  rủi   N  0.33  0.55  0.70    0.075227
# 128                  tum             chân_vịt   N  0.47  0.78  0.62    0.181655
# 129                 nhạo                  vèo   V  0.80  1.33  1.33    0.154517
# 130             ngoại_lệ            thường_lệ   N  0.67  1.12  0.87   -0.037168
# 131             phong_độ           phong_thái   N  4.27  7.12  1.00    0.370127
# 132              biết_ơn                vô_ơn   V  0.20  0.33  0.54    0.286011
# 133              buồn_bã             nối_tiếp   V  1.67  2.78  0.70    0.099909
# 134                 quay         chuyển_hướng   N  4.40  7.33  1.20    0.296198
# 135             tập_dượt            tập_luyện   V  4.87  8.12  0.96    0.434315
# 136              oxy_hoá             đổi_thay   V  3.27  5.45  1.12    0.119864
# 137                  trà                  bụi   N  1.07  1.78  1.24    0.222227
# 138                phỏng                 mảnh   A  0.87  1.45  0.88    0.081764
# 139            phòng_ngủ       công_trình_phụ   N  2.80  4.67  0.54    0.281539
# 140             hình_hoạ             cung_bậc   N  0.53  0.88  0.96    0.168026
# 141                  hoạ                 phúc   N  0.53  0.88  0.88    0.116998
# 142              nửa_mùa            đồng_điệu   A  1.07  1.78  1.18   -0.011829
# 143           thịnh_hành             hữu_tình   A  0.53  0.88  0.96    0.077732
# 144              biệt_ly              sum_họp   V  0.47  0.78  0.81    0.000000
# 145              phụ_bản               nếp_tẻ   N  0.47  0.78  1.09    0.000000
# 146              lời_lãi              thua_lỗ   N  0.40  0.67  0.71    0.266508
# 147            con_đường               vỉa_hè   N  2.53  4.22  0.88    0.311741
# 148          chính_nghĩa            phi_nghĩa   N  0.47  0.78  0.88    0.557049
# 149            trần_gian               cõi_âm   N  0.73  1.22  0.77    0.346244
# 150                vượng                  suy   V  0.53  0.88  1.02    0.008038
# 151            lắng_nghe             lắng_tai   V  4.67  7.78  0.87    0.000000
# 152               ấp_úng                  nói   V  2.33  3.88  0.87    0.210514
# 153             thất_bại           thành_công   N  0.53  0.88  1.26    0.466457
# 154              đa_ngôn            mỏng_tang   A  0.27  0.45  0.57    0.000000
# 155                ái_mộ               hâm_mộ   V  5.07  8.45  0.68    0.469165
# 156                tí_ti               tí_teo   N  5.13  8.55  1.02    0.000000
# 157              nỗi_đau              tai_hoạ   N  3.20  5.33  1.05    0.490304
# 158           dương_gian               cõi_âm   N  0.67  1.12  1.07    0.000000
# 159              phân_tử               nếp_tẻ   N  0.13  0.22  0.50    0.000000
# 160              định_kỳ           bất_thường   N  0.73  1.22  1.06    0.143864
# 161                trước                  sau   N  0.33  0.55  0.47    0.576604
# 162            đánh_bóng              làm_đẹp   V  4.20  7.00  1.22    0.382144
# 163                 đoán             quan_sát   V  3.93  6.55  0.68    0.320328
# 164              đồ_dùng               đồ_vật   N  2.33  3.88  0.94    0.574949
# 165             giải_tán              tập_hợp   V  0.67  1.12  1.07    0.193897
# 166                 nhóm             liên_kết   V  0.33  0.55  0.79    0.241648
# 167             đầu_tiên            cuối_cùng   N  0.47  0.78  0.72    0.510663
# 168              hảo_hữu           người_thân   N  2.40  4.00  1.14    0.000000
# 169                quyển                  bìa   N  2.00  3.33  0.82    0.209403
# 170           vượt_tuyến              hằn_học   V  0.40  0.67  0.61   -0.029710
# 171            chiến_bại            thắng_lợi   V  1.07  1.78  1.06    0.283702
# 172              bành_tô                 khăn   N  2.20  3.67  1.22    0.000000
# 173               đỡ_đần            bình_luận   V  0.53  0.88  0.88    0.017015
# 174                   hạ                 tăng   V  0.67  1.12  0.94    0.359869
# 175                  tợn                 hiền   A  0.40  0.67  0.80    0.000000
# 176              bội_bạc           chung_thuỷ   A  0.47  0.78  0.62    0.339789
# 177              nhà_máy           dây_chuyền   N  2.53  4.22  0.72    0.359462
# 178              tàu_hoả         xe_điện_ngầm   N  3.93  6.55  1.12    0.421911
# 179                 thuở                 thủa   N  5.87  9.78  0.34    0.861469
# 180                tranh            trông_nom   V  1.93  3.22  0.77   -0.033363
# 181          cây_thân_gỗ                 cành   N  2.53  4.22  0.88    0.000000
# 182                 xuôi                ngược   N  0.33  0.55  0.60    0.314797
# 183            biên_nhận                  móc   V  0.40  0.67  0.88    0.003813
# 184             thi_hành                  bắt   V  3.40  5.67  1.14    0.058758
# 185             cự_tuyệt               bãi_bỏ   V  3.67  6.12  1.14    0.396839
# 186              thi_đấu              phá_vây   V  0.80  1.33  0.83    0.000000
# 187           hiện_trạng            tình_cảnh   N  4.40  7.33  1.31    0.196726
# 188           vượt_tuyến             dứt_điểm   V  1.00  1.67  0.89    0.259332
# 189              cá_hồng              cá_chai   N  3.40  5.67  1.08    0.000000
# 190                 bằng             văn_bằng   N  4.60  7.67  0.49    0.055385
# 191           tĩnh_dưỡng              lộn_xộn   V  1.73  2.88  0.85   -0.021295
# 192              bạc_đãi            trọng_đãi   V  0.67  1.12  0.79    0.000000
# 193              phân_li              đoàn_tụ   V  0.53  0.88  0.88    0.000000
# 194                 nhốt                  thả   V  0.53  0.88  1.09    0.398285
# 195             nội_tiết                huyệt   N  1.07  1.78  0.77    0.189028
# 196              phụ_bản         truyện_tranh   N  1.93  3.22  1.29    0.347429
# 197            phong_thư              địa_chỉ   N  2.93  4.88  0.68    0.249749
# 198            thời_bình           thời_chiến   N  0.73  1.22  0.77    0.608920
# 199              áo_quan             quan_tài   N  3.93  6.55  0.85    0.675583
# 200             trẩy_hội                   ví   V  0.27  0.45  0.57    0.053141
# 201            nhức_nhối            nhấp_nhỏm   A  1.93  3.22  1.24    0.000000
# 202                cũ_kỹ               mới_mẻ   A  0.33  0.55  0.60    0.323291
# 203                 nhạo               hạ_bút   V  0.80  1.33  0.83    0.000000
# 204         sân_vận_động             khán_đài   N  2.33  3.88  0.70    0.570700
# 205  chủ_nghĩa_hình_thức         truyện_tranh   N  1.53  2.55  1.26    0.000000
# 206                 được                  mất   V  0.40  0.67  0.49   -0.005104
# 207                 hiểu           tiên_lượng   V  2.47  4.12  1.31    0.252627
# 208             quét_dọn              loại_bỏ   V  3.73  6.22  0.85    0.045426
# 209              bay_hơi                  bay   V  3.47  5.78  0.72    0.148531
# 210              dễ_dàng             khó_khăn   A  0.67  1.12  1.25    0.426879
# 211                   gạ               gạ_gẫm   V  5.33  8.88  0.60    0.670065
# 212            vắng_tanh            lịch_bịch   A  0.47  0.78  0.72    0.000000
# 213            nhậm_chức           nhiệm_chức   V  4.67  7.78  1.07    0.314163
# 214                hồ_sơ              bằng_cớ   N  4.07  6.78  0.57    0.000000
# 215              hổ_thẹn             bắt_buộc   V  0.60  1.00  0.88    0.288237
# 216             dấu_hiệu            đặc_trưng   N  3.20  5.33  0.75    0.124750
# 217            người_dân            tộc_người   N  3.87  6.45  1.09    0.345238
# 218              bè_cánh             vây_cánh   N  4.67  7.78  0.94    0.000000
# 219              bật_lửa             giảm_xóc   N  2.60  4.33  1.14    0.176791
# 220        sinh_vật_cảnh          không_trung   N  0.60  1.00  0.80    0.071062
# 221             chần_chờ            dứt_khoát   V  0.40  0.67  0.80   -0.081508
# 222               tư_thế           phong_thái   N  5.00  8.33  0.63    0.335667
# 223          máy_vi_tính                 phím   N  2.80  4.67  0.65    0.233201
# 224               sụp_đổ              kìm_nén   V  2.20  3.67  1.05    0.221376
# 225              mắc_kẹt              cầm_giữ   V  5.33  8.88  0.87    0.474635
# 226             hình_hoạ            khí_quyển   N  0.27  0.45  0.57    0.093293
# 227            thuộc_địa             kiều_dân   N  3.93  6.55  1.24    0.320389
# 228              nhà_hát             sân_khấu   N  2.60  4.33  1.02    0.440648
# 229                 thìa                muỗng   N  4.67  7.78  0.87    0.842298
# 230                   tỏ              biểu_lộ   V  4.80  8.00  1.11    0.497575
# 231          chiến_tranh           trận_chiến   N  2.73  4.55  0.68    0.411558
# 232                  cộc                   va   V  5.00  8.33  0.89    0.034026
# 233              tính_sổ        giám_đốc_thẩm   V  1.27  2.12  1.12    0.030978
# 234                  hơn                 thua   A  0.80  1.33  1.22    0.086052
# 235             cựu_binh             tân_binh   N  0.67  1.12  0.79    0.455814
# 236              tính_sổ           nuôi_dưỡng   V  0.60  1.00  0.95    0.074386
# 237             ngữ_cảnh             văn_cảnh   N  4.73  7.88  0.93    0.000000
# 238             hâm_nóng             cải_biến   V  3.20  5.33  1.22    0.390974
# 239                  bón                  tẩm   V  0.93  1.55  0.85    0.226872
# 240                 thảm             thê_thảm   A  5.73  9.55  0.44    0.218243
# 241              lắp_đặt            nhồi_nhét   V  3.53  5.88  0.88    0.089135
# 242              tạo_hoá              tạo_vật   N  2.60  4.33  1.25    0.299025
# 243                  hen                  cúm   N  3.87  6.45  1.20    0.339309
# 244              mệt_mỏi              mỏi_mệt   A  5.73  9.55  0.77    0.774154
# 245            tắc_nghẽn           thông_suốt   V  0.40  0.67  0.61    0.364597
# 246                trọng            coi_trọng   V  5.60  9.33  0.61    0.382431
# 247                  đẽo                  bắt   V  0.73  1.22  0.93    0.064993
# 248             len_lách              len_lỏi   V  5.00  8.33  0.97    0.000000
# 249                   hú                   ca   V  3.87  6.45  0.96    0.146425
# 250            danh_sách                  mục   N  3.13  5.22  0.81    0.251903
# 251        chuyển_nhượng             phát_mại   V  3.13  5.22  0.96    0.182577
# 252             vòng_tay            trang_sức   N  4.13  6.88  1.15    0.112026
# 253           đổ_bê_tông             chăm_sóc   V  1.13  1.88  1.20    0.055979
# 254                  kín                 phát   V  0.80  1.33  0.91    0.018338
# 255           người_tình             chiến_sĩ   N  2.87  4.78  0.88    0.106257
# 256                 cuối                  đầu   N  0.53  0.88  0.72    0.642395
# 257              cần_tây              đậu_bắp   N  2.93  4.88  0.77    0.550254
# 258              định_kì           bất_thường   N  0.67  1.12  1.14    0.158563
# 259            thiện_chí                 ác_ý   N  0.60  1.00  0.88    0.304747
# 260           biên_cương            biên_giới   N  5.33  8.88  0.60    0.355631
# 261                 sông             cửa_sông   N  2.67  4.45  1.14    0.640859
# 262                  tím                  bẹp   A  0.73  1.22  1.06    0.108127
# 263          năm_âm_lịch        tháng_âm_lịch   N  2.40  4.00  0.88    0.571929
# 264               đỡ_đần              suy_xét   V  0.73  1.22  1.06    0.154690
# 265                  bầm                   mệ   N  5.60  9.33  0.61    0.041452
# 266                 dáng               tản_bộ   N  3.73  6.22  0.93    0.100917
# 267             sinh_vật               tế_bào   N  2.80  4.67  0.75    0.498718
# 268              giở_quẻ            giở_chứng   V  5.47  9.12  0.62    0.000000
# 269                 nhau                  rau   N  4.73  7.88  0.68    0.116307
# 270            đồng_tình             phản_đối   A  0.67  1.12  0.94    0.290639
# 271                thanh              dụng_cụ   N  3.07  5.12  0.68    0.148197
# 272                 điệu                  háo   A  1.00  1.67  1.21    0.108023
# 273              tử_trận             tiếp_sức   V  0.40  0.67  0.71    0.083077
# 274              trù_dập               trù_úm   V  5.40  9.00  0.71    0.596376
# 275               tứ_kết             trận_đấu   N  3.47  5.78  1.02    0.400695
# 276              tình_ca              ca_khúc   N  3.67  6.12  1.25    0.483184
# 277               báo_ân              trả_thù   V  1.07  1.78  1.18    0.086930
# 278             vững_tâm            vững_lòng   A  5.53  9.22  0.72    0.415417
# 279              cũ_rích               mới_mẻ   A  0.67  1.12  0.79    0.193455
# 280                 lành                  kẹt   A  0.27  0.45  0.44    0.028053
# 281                   tù                 ngục   N  5.53  9.22  0.88    0.307555
# 282  chủ_nghĩa_hình_thức             đức_tính   N  1.27  2.12  1.34    0.000000
# 283              dày_cộp            mỏng_tang   A  0.47  0.78  0.72    0.317442
# 284            cây_trồng  thầy_thuốc_nhân_dân   N  0.87  1.45  0.96    0.091415
# 285            điều_hành              lục_lọi   N  2.47  4.12  0.72    0.012591
# 286              dáng_bộ            dáng_điệu   N  5.00  8.33  1.21    0.000000
# 287                tự_do            phần_cứng   N  0.47  0.78  0.62    0.003562
# 288             thu_ngân               dân_cư   N  2.47  4.12  1.20    0.100909
# 289                  cắt                  tẩm   V  0.27  0.45  0.57    0.105043
# 290           nghị_quyết             tài_liệu   N  3.47  5.78  0.81    0.165715
# 291              ăn_nhậu            nhậu_nhẹt   V  4.47  7.45  0.62    0.728321
# 292              gắn_kết             liên_kết   V  5.47  9.12  0.88    0.687693
# 293             máy_tính          bộ_vi_xử_lý   N  2.67  4.45  0.79    0.507746
# 294            cải_thiện            thuần_hoá   V  2.20  3.67  0.83    0.214084
# 295             năng_lực               tột_độ   N  1.73  2.88  0.68   -0.013590
# 296             an_dưỡng           tĩnh_dưỡng   V  5.13  8.55  1.09    0.546165
# 297            di_chuyển                  dời   N  5.27  8.78  0.68    0.339194
# 298                ngoài                trong   N  0.60  1.00  0.71    0.121216
# 299                  cặp                  đôi   N  5.73  9.55  0.57    0.375194
# 300                 cẳng             bắp_chân   N  2.80  4.67  0.65    0.303971
# 301          chiến_tranh             hoà_bình   N  0.47  0.78  0.62    0.345820
# 302              đau_đớn            làm_phiền   V  5.20  8.67  0.83    0.069406
# 303             gia_tăng             lạm_phát   V  2.67  4.45  1.07    0.198630
# 304                 thói              thái_độ   N  2.60  4.33  1.25    0.437752
# 305              mô_hình             cấu_trúc   N  4.07  6.78  0.85    0.421301
# 306             mạo_danh              lừa_đảo   V  4.47  7.45  1.09    0.607596
# 307                  sếp             lãnh_đạo   N  4.27  7.12  0.77    0.324898
# 308                  thẻ               kỉ_vật   N  2.60  4.33  0.95    0.111219
# 309                  hỏi                  đáp   V  0.67  1.12  0.87    0.403758
# 310               tản_bộ            di_chuyển   V  3.47  5.78  0.96    0.389444
# 311         chuệch_choạc          chệch_choạc   A  5.53  9.22  0.50    0.773368
# 312           dương_gian               âm_phủ   N  0.53  0.88  0.62    0.000000
# 313           giải_thích                 ngấm   V  0.47  0.78  0.72    0.094371
# 314                 mách            mách_nước   V  4.20  7.00  0.91    0.530571
# 315             nước_lớn              xuất_xứ   N  1.00  1.67  1.21    0.083489
# 316               số_hoá             hoá_lỏng   V  1.60  2.67  0.61    0.138554
# 317                  dận                 nhấn   V  4.67  7.78  0.79    0.000000
# 318            hơi_hướng              hơi_hám   N  0.73  1.22  0.77    0.000000
# 319             cắt_giảm              trừ_khử   V  0.53  0.88  0.96    0.159335
# 320             nhạc_nhẹ             cung_bậc   N  1.40  2.33  1.20    0.151727
# 321              túm_tụm              quần_tụ   V  5.00  8.33  0.82    0.339669
# 322              giở_mặt             lật_lọng   V  5.00  8.33  1.26    0.000000
# 323             thị_giác             võng_mạc   N  2.87  4.78  0.72    0.450930
# 324            người_làm             dân_chơi   N  2.13  3.55  1.09    0.155087
# 325            phân_chia              phân_bổ   N  5.07  8.45  0.77    0.528467
# 326             xâm_nhập                xuyên   V  4.20  7.00  0.98    0.199204
# 327             thuộc_hạ            người_lớn   N  1.93  3.22  0.93    0.200464
# 328          dịch_chuyển             tham_gia   V  1.33  2.22  0.79    0.031248
# 329                  bơi                 ngụp   V  3.47  5.78  1.36    0.440576
# 330               cư_dân            người_dân   N  5.67  9.45  0.60    0.583458
# 331           khoan_thai             ung_dung   A  5.27  8.78  0.85    0.315038
# 332               xe_tải                  nóc   N  1.53  2.55  1.02    0.131024
# 333             mùa_đông             đông_chí   N  2.67  4.45  0.70    0.339149
# 334              lạc_hậu            tiên_tiến   A  0.53  0.88  0.62    0.299426
# 335            chọc_ghẹo             biếu_xén   V  0.67  1.12  0.94    0.250476
# 336                  nền             cận_cảnh   N  1.80  3.00  0.75   -0.117092
# 337                sư_tử            lăng_kính   N  0.80  1.33  1.17    0.007990
# 338                  bẫy                  cạm   N  5.00  8.33  0.63    0.000000
# 339             nhảy_múa             nhẩy_múa   V  4.60  7.67  0.95    0.000000
# 340             minh_oan              phá_vây   V  0.33  0.55  0.47    0.000000
# 341          nguyên_nhân            nguyên_do   N  5.93  9.88  0.25    0.817989
# 342                   dữ                 hiền   A  0.80  1.33  1.28    0.150427
# 343             phần_phụ              bộ_phận   N  4.07  6.78  0.85    0.199143
# 344             anh_dũng            dũng_mãnh   A  5.13  8.55  0.72    0.148077
# 345             buôn_bán              vận_tải   N  2.40  4.00  0.80    0.190018
# 346           khấp_khểnh            gập_ghềnh   A  5.47  9.12  0.72    0.000000
# 347              đâm_sầm                phóng   V  3.40  5.67  1.31    0.324458
# 348                   bò                   đi   V  2.60  4.33  1.02   -0.000811
# 349               yểm_hộ              yểm_trợ   V  5.00  8.33  0.89    0.000000
# 350            vòng_vòng           ngoại_tiếp   A  1.80  3.00  1.28    0.000000
# 351             nội_tiết                luồng   N  1.07  1.78  1.06    0.005273
# 352               dị_ứng            lương_tri   N  0.33  0.55  0.60   -0.011614
# 353             trẩy_hội            ứng_chiến   V  0.53  0.88  0.72    0.000000
# 354                  vặn              vặn_vẹo   V  4.13  6.88  1.15    0.332966
# 355            lùng_bùng            vắng_ngắt   A  1.60  2.67  1.14    0.179950
# 356                  chê                 khen   V  0.13  0.22  0.34    0.258115
# 357            tượng_đài        bảng_tổng_sắp   N  0.80  1.33  1.05    0.063625
# 358            người_yêu            tình_nhân   N  3.00  5.00  1.10    0.407406
# 359            thiện_cảm               ác_cảm   N  0.53  0.88  0.72    0.590968
# 360           trau_chuốt           phát_triển   V  2.07  3.45  0.93    0.133535
# 361                 gươm                 lưỡi   N  1.40  2.33  1.02    0.252180
# 362              bánh_xe                 vành   N  2.60  4.33  0.95    0.462155
# 363            tượng_đài             phân_bón   N  0.07  0.12  0.25   -0.086081
# 364                  nạc                  búi   A  0.60  1.00  0.80    0.143593
# 365          khung_thành              cầu_môn   N  5.40  9.00  1.25    0.905729
# 366                   kĩ               sơ_sài   A  0.20  0.33  0.40    0.357610
# 367                 buồn                  vui   A  0.20  0.33  0.54    0.632507
# 368           nhược_điểm              ưu_điểm   N  0.33  0.55  0.79    0.697044
# 369              quan_hệ           trạng_thái   N  2.73  4.55  0.68    0.179219
# 370             đong_đưa             vung_vẩy   V  3.93  6.55  1.24    0.372504
# 371              bừa_bãi              gọn_ghẽ   A  0.27  0.45  0.44    0.164286
# 372          nghiêm_lệnh             đồng_dao   N  1.07  1.78  1.06    0.000000
# 373              nhà_thơ             thi_nhân   N  4.87  8.12  0.81    0.654199
# 374             máy_tính             vi_xử_lý   N  2.40  4.00  0.61    0.437247
# 375             né_tránh                 hích   V  2.60  4.33  1.14    0.087134
# 376                 địch                   ta   N  0.33  0.55  0.70    0.341037
# 377            lưu_thông              ách_tắc   V  0.53  0.88  1.02    0.294617
# 378              thứ_yếu             rộng_rãi   A  0.20  0.33  0.40    0.038547
# 379             đặt_chân                 thay   V  3.27  5.45  1.24    0.206224
# 380               dì_ghẻ            phụ_huynh   N  3.80  6.33  0.91    0.243767
# 381                  rỗi              rỗi_rãi   A  5.53  9.22  0.72    0.515167
# 382             tái_phát          nhiễm_khuẩn   V  0.87  1.45  0.72    0.409516
# 383                  mầm              rau_quả   N  3.53  5.88  1.02    0.199947
# 384              hạn_hán              lụt_lội   N  0.33  0.55  0.60    0.674216
# 385             lưỡng_lự            dứt_khoát   V  0.27  0.45  0.57    0.230616
# 386                 tung             cấp_phát   V  3.93  6.55  0.68    0.183572
# 387                 giầu                  khó   A  0.53  0.88  0.72    0.136968
# 388              làm_đẹp              cải_tạo   V  2.40  4.00  1.02    0.184590
# 389              ban_mai              sớm_mai   N  5.40  9.00  1.08    0.476712
# 390                  quỳ                   ví   V  1.00  1.67  1.26    0.056714
# 391               bại_lộ                   lộ   V  5.07  8.45  1.24    0.470767
# 392            tính_cách            phẩm_chất   N  4.40  7.33  1.14    0.494447
# 393            triều_đại               cổ_đại   N  3.67  6.12  1.14    0.274376
# 394            cõi_dương               cõi_âm   N  0.60  1.00  1.20    0.000000
# 395            lình_xình            nặng_tình   A  1.33  2.22  1.14    0.170494
# 396            người_làm         người_bị_hại   N  2.20  3.67  0.83    0.135008
# 397              cõi_tục            trần_gian   N  5.40  9.00  0.71    0.000000
# 398             chần_chừ              lảo_đảo   V  3.20  5.33  0.98    0.112939
# 399            khử_trùng            sát_trùng   V  5.53  9.22  0.81    0.705227

# %%
def sim2word(word1, word2, sim_f=cosine):
    vec1 = word2vec(word1)
    if not np.any(vec1):
        print('vec1')
        vec1 = vec_estimate(word1)

    vec2 = word2vec(word2)
    if not np.any(vec2):
        print('vec2')
        vec2 = vec_estimate(word2)

    return sim_f(vec1, vec2)

# %%
sim2word('cõi_tục', 'trần_gian')
# Out:
# vec1
# 0.6957755493627643

# %%
word1 = sim_pairs['Word1'].to_list()
word2 = sim_pairs['Word2'].to_list()

# %%
cosine_sim = []

# %%
for i in tqdm(range(400)):
    print(sim2word(word1[i], word2[i]))
# Out:
#  11%|█▏        | 45/400 [00:00<00:00, 387.77it/s]
# -0.004912339469670016
# 0.08252318329211772
# 0.27708595986827755
# 0.17679862835626714
# vec1
# 0.6060296673640085
# 0.4023661291943061
# 0.46300840201407223
# 0.25694700889961236
# 0.18519202240211616
# 0.22306960452548544
# 0.5348913029963394
# 0.07770108930396213
# vec2
# 0.0
# vec1
# 0.0
# 0.6438835401838533
# 0.3610325527728171
# 0.059602370849219294
# 0.23895503536998705
# 0.16647413914742729
# -0.17284007209619465
# 0.6417888034717878
# 0.28753527791057554
# 0.3881971694440945
# 0.25596472879600973
# 0.48043194238556175
# 0.47242629887420834
# 0.662409385234064
# 0.22523314998167998
# vec1
# 0.0
# 0.7340683342360697
# -0.013609544519483876
# 0.6878254420258126
# 0.5964044436335486
# 0.37544414221247063
# 0.38561358220504466
# 0.23305646417105497
# -0.030257136838635332
# 0.0923981505332208
# 0.4812901949758729
# 0.4430288482597332
# 0.4276402056214263
# 0.34353721462857584
# 0.47775360404332445
# 0.16598255399110182
# vec1
# vec2
# 0.0
# 0.35188002162814613
# vec2
#  12%|█▏        | 46/400 [00:57<07:22,  1.25s/it]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Things\PyProject\Word-Similarity\src\word2vec-load.ipynb Cell 3' in word2vec(a)
#      <a href='vscode-notebook-cell:/d%3A/Things/PyProject/Word-Similarity/src/word2vec-load.ipynb#ch0000002?line=20'>21</a> try:
# ---> <a href='vscode-notebook-cell:/d%3A/Things/PyProject/Word-Similarity/src/word2vec-load.ipynb#ch0000002?line=21'>22</a>     idx = words.index(a)
#      <a href='vscode-notebook-cell:/d%3A/Things/PyProject/Word-Similarity/src/word2vec-load.ipynb#ch0000002?line=22'>23</a>     return vecs[idx]
#
# ValueError: None is not in list
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Things\PyProject\Word-Similarity\src\word2vec-load.ipynb Cell 17' in <cell line: 1>()
#       <a href='vscode-notebook-cell:/d%3A/Things/PyProject/Word-Similarity/src/word2vec-load.ipynb#ch0000027?line=0'>1</a> for i in tqdm(range(400)):
# ----> <a href='vscode-notebook-cell:/d%3A/Things/PyProject/Word-Similarity/src/word2vec-load.ipynb#ch0000027?line=1'>2</a>     print(sim2word(word1[i], word2[i]))
#
# d:\Things\PyProject\Word-Similarity\src\word2vec-load.ipynb Cell 13' in sim2word(word1, word2, sim_f)
#       <a href='vscode-notebook-cell:/d%3A/Things/PyProject/Word-Similarity/src/word2vec-load.ipynb#ch0000022?line=7'>8</a> if not np.any(vec2):
#       <a href='vscode-notebook-cell:/d%3A/Things/PyProject/Word-Similarity/src/word2vec-load.ipynb#ch0000022?line=8'>9</a>     print('vec2')
# ---> <a href='vscode-notebook-cell:/d%3A/Things/PyProject/Word-Similarity/src/word2vec-load.ipynb#ch0000022?line=9'>10</a>     vec2 = vec_estimate(word2)
#      <a href='vscode-notebook-cell:/d%3A/Things/PyProject/Word-Similarity/src/word2vec-load.ipynb#ch0000022?line=11'>12</a> return sim_f(vec1, vec2)
#
# d:\Things\PyProject\Word-Similarity\src\word2vec-load.ipynb Cell 10' in vec_estimate(word)
#      <a href='vscode-notebook-cell:/d%3A/Things/PyProject/Word-Similarity/src/word2vec-load.ipynb#ch0000010?line=11'>12</a>     return np.zeros(dim)
#      <a href='vscode-notebook-cell:/d%3A/Things/PyProject/Word-Similarity/src/word2vec-load.ipynb#ch0000010?line=13'>14</a> ant_2 = get_synonym(ant_1)
# ---> <a href='vscode-notebook-cell:/d%3A/Things/PyProject/Word-Similarity/src/word2vec-load.ipynb#ch0000010?line=14'>15</a> while not np.any(word2vec(ant_2)):
#      <a href='vscode-notebook-cell:/d%3A/Things/PyProject/Word-Similarity/src/word2vec-load.ipynb#ch0000010?line=15'>16</a>     ant_2 = get_synonym(ant_2)
#      <a href='vscode-notebook-cell:/d%3A/Things/PyProject/Word-Similarity/src/word2vec-load.ipynb#ch0000010?line=17'>18</a> if not np.any(word2vec(ant_2)):
#
# d:\Things\PyProject\Word-Similarity\src\word2vec-load.ipynb Cell 3' in word2vec(a)
#      <a href='vscode-notebook-cell:/d%3A/Things/PyProject/Word-Similarity/src/word2vec-load.ipynb#ch0000002?line=22'>23</a>     return vecs[idx]
#      <a href='vscode-notebook-cell:/d%3A/Things/PyProject/Word-Similarity/src/word2vec-load.ipynb#ch0000002?line=23'>24</a> except:
# ---> <a href='vscode-notebook-cell:/d%3A/Things/PyProject/Word-Similarity/src/word2vec-load.ipynb#ch0000002?line=24'>25</a>     return np.zeros(dim)
#
# KeyboardInterrupt:
