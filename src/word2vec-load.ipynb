# %%
from base64 import encode
import os
import pandas as pd

# %%
with open('../word2vec/W2V_150.txt', 'r', encoding='utf-8') as w2v:
    w2v_data = w2v.readlines()

num_word = w2v_data[0]
vec_dim = w2v_data[1]

w2v_data_frame = []
for line in w2v_data[2:]:
    word_vector = line.split(' ')[:-1]
    w2v_data_frame.append(word_vector)
word2vec_df = pd.DataFrame(w2v_data_frame)
word2vec_df.head()
# Out:
#          0   1          2           3           4           5           6    \
# 0      những      0.2901038  -0.2898787   0.4169351     1.93689   0.4440359
# 1    tiết_lộ      -1.308045   0.9506664      2.3402  -0.4334157  -0.2442499
# 2     thú_vị       2.561394    2.765394   -2.260592    1.895223     1.02471
# 3         về      -1.414575  -0.5932151    -1.40398   -1.300985   0.9467459
# 4  wallpaper      0.2554106   -1.367197  -0.6043473   0.9219519   0.1584521
#
#          7           8            9    ...         142         143  \
# 0   1.187533   -1.278718   -0.3357244  ...  -0.4676817  -0.7147113
# 1   1.175481   -0.393907     -2.15717  ...   -2.070473  -0.8077184
# 2  0.6827917  -0.6990096    -1.019593  ...   0.3214183    0.312818
# 3  0.1599043  -0.6800195    0.4721075  ...  -0.4536858   0.7370188
# 4  0.1298264   0.2229709  -0.02587517  ...  -0.4391974    1.027919
#
#           144         145         146         147         148          149  \
# ...

# %%
vi_sim_df = pd.read_csv('../datasets/ViSim-400/Visim-400.txt', delim_whitespace=True)
vi_sim_df.head()
# Out:
#          Word1   Word2 POS  Sim1  Sim2   STD
# 0         biến    ngập   V  3.13  5.22  0.72
# 1  nhà_thi_đấu     nhà   N  3.07  5.12  1.18
# 2         động    tĩnh   V  0.60  1.00  0.95
# 3       khuyết      ưu   N  0.20  0.33  0.40
# 4      cõi_tục  cõi_âm   N  0.60  1.00  0.95
