# %%
import fasttext
import fasttext.util

# %%
fasttext.util.download_model('vi', if_exists='ignore')
ft = fasttext.load_model('cc.vi.300.bin')
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
from base64 import encode
import os
import pandas as pd
import numpy as np
from typing import Callable, List
from tqdm import tqdm
import scipy
from scipy import stats
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder(handle_unknown='ignore',sparse=False)

# %%
word2vecpath = '../word2vec/W2V_150.txt'
antsynpath = '../antonym-synonym set'
visimpath = '../datasets/ViSim-400'
viconpath = '../datasets/ViCon-400'

# %%
words = []
vecs = []

dim = None
n_vocab = None

with open(word2vecpath, encoding='utf8') as f:
    for line in tqdm(f, f"loading {word2vecpath} to variables"):
        if not n_vocab:
            n_vocab = int(line)
        elif not dim:
            dim = int(line)
        else:
            line = line.replace('\n', '')
            word = line.split('  ')[0]
            words.append(word)
            vecs.append(ft.get_word_vector(word))
vecs = np.array(vecs)
# Out:
# loading ../word2vec/W2V_150.txt to variables: 77023it [00:01, 47764.42it/s]

# %%
np.save('words', words)
np.save('vectors', vecs)

# %%
vecs.shape
# Out:
# (77021, 300)

# %%
def word2vec(a: str) -> np.array:
    try:
        i = words.index(a)
        return vecs[i]
    except:
        return np.zeros(300)


def cosine(a: np.array, b: np.array) -> float:
    a = a / np.linalg.norm(a) if np.linalg.norm(a) != 0 else a
    b = b / np.linalg.norm(b) if np.linalg.norm(b) != 0 else b
    return a.dot(b)

def sim(row, sim_f=cosine):
    vec1 = word2vec(row.iloc[0])
    vec2 = word2vec(row.iloc[1])

    return sim_f(vec1, vec2)

# %%
sim_pairs = pd.read_csv(visimpath + '/Visim-400.txt', sep="\t")

# %%
sim_pairs['cosine'] = sim_pairs.apply(sim, axis=1, sim_f=cosine)
print(sim_pairs.to_string())

# %%
ant_pairs = pd.read_csv('../antonym-synonym set/Antonym_vietnamese.txt', 
                        delim_whitespace=True, header = None, 
                        names=['Word1', 'Word2'])
ant_pairs['Relation'] = 'ANT'


syn_pairs = pd.read_csv('../antonym-synonym set/Synonym_vietnamese.txt',
                        delim_whitespace=True, header = None, 
                        names=['Word1', 'Word2'])
syn_pairs['Relation'] = 'SYN'

train_dataset = pd.concat([ant_pairs, syn_pairs])

train_dataset = train_dataset.dropna()
train_dataset = train_dataset.sample(frac=1)
train_dataset = train_dataset.reset_index(drop=True)

# %%
noun_pairs = pd.read_csv(viconpath + '/400_verb_pairs.txt', sep="\t")
verb_pairs = pd.read_csv(viconpath + '/400_verb_pairs.txt', sep="\t")
adj_pairs = pd.read_csv(viconpath + '/600_adj_pairs.txt', sep="\t")

test_dataset =  pd.concat([noun_pairs, verb_pairs, adj_pairs])

test_dataset = test_dataset.dropna()
test_dataset = test_dataset.sample(frac=1)
test_dataset = test_dataset.reset_index(drop=True)

# %%
train_vec2 = train_dataset['Word2'].tolist()

# %%
print(train_vec2)

# %%
x_train_vec2 = np.array([ft.get_word_vector(train_vec2[i]) for i in range(len(train_vec2))])

# %%
train_vec1 = train_dataset['Word1'].tolist()
# train_vec2 = train_dataset['Word2'].tolist()

x_train_vec1 = np.array([ft.get_word_vector(train_vec1[i]) for i in range(len(train_vec1))])
# x_train_vec2 = np.array([ft.get_word_vector(train_vec2[i]) for i in range(len(train_vec2))])

# x_train_vec = np.array([[a, b] for a, b in zip(x_train_vec1, x_train_vec2)])
# np.save('x_train_vec', x_train_vec)

# %%
train_vec2 = train_dataset['Word2'].tolist() 

for i in train_vec2:
    print(i)
    ft.get_word_vector(i)
# Out:
# điện_tín
# giao_thông
# ni_sư
# mệ
# thịch
# hay
# tỷ_trọng
# cuộc_thế
# tý
# hoạ
# mỹ_tục
# cú
# cuối_cùng
# đẩn
# thanh
# bảo_nhỏ
# lẩn_lút
# đỉnh_điểm
# móc_ngoặc
# vơi
# bè_phái
# tân_binh
# thầm_thì
# hẹp_hòi
# dũng_cảm
# quạnh_vắng
# trước
# tuyệt_mỹ
# rỗi
# sượng_mặt
# đắn_đo
# lội_bộ
# khắt_khe
# kềm_chế
# lộ_thiên
# phó_thác
# nhọc_lòng
# dính_dấp
# khi_dể
# nháo_nhào
# hữu_lí
# tột_đỉnh
# gan_liền
# vô_lễ
# chĩnh_chện
# che_đậy
# y_lý
# lủn_mủn
# đền_bù
# mẽ
# xúc_tiến
# dài_ngoẵng
# thảo_luận
# chứng_cứ
# ních
# khuyến_khích
# lãnh_hải
# rối_tinh
# ạ_ơi
# bài_xuất
# hữu_ích
# dấu_chấm_lửng
# ẫm_ờ
# vị_tha
# thanh_vắng
# trần_truồng
# sạch_sẽ
# đái_láu
# vị_lai
# túng_quẫn
# kỹ_tính
# thanh_hao
# chấp_nhận
# xịch
# khâm_phục
# bãi_thị
# tù_đầy
# tiếc_nuối
# mé
# sa_sả
# xờ_xạc
# e-mail
# vô_vọng
# nỏ_miệng
# phê_chuẩn
# ác_một_cái_là
# hẹp_hòi
# móc_câu
# vật_chứng
# chuyên_dụng
# nguồn_cơn
# nồng_hậu
# loạng_choạng
# xỉ
# mừng
# tráng_lệ
# y_chang
# đồng_tính
# kỹ_năng
# vô_trùng
# thần_sắc
# bóp_miệng
# sô
# đặc_sệt
# chùi
# áp_điệu
# sáng
# danh_tính
# nhọn
# thông_suốt
# sầu
# lam_chướng
# tự_ý
# kiên_nghị
# thăng_thiên
# u
# trương_mục
# chán_phèo
# loăng_quăng
# kết_thúc
# khập_khễnh
# vắng_mặt
# thổ_thần
# tom_góp
# kỳ_thực
# mạnh_bạo
# phái
# sai
# mong_đợi
# bổ_nhào
# nếu_như
# nhất_quyết
# phá_ngang
# ước_tính
# động_đực
# cửa_mình
# trưởng_tộc
# dài_thượt
# làu_bàu
# cứng_nhắc
# đá_hoa
# van_vỉ
# nhiệt_độ_Celsius
# lòm_khòm
# ăn_thua
# nô_đùa
# ước
# hốt_nhiên
# nhập_nội
# tỷ_như
# ơ_kìa
# then_chốt
# chờm
# đun_đẩy
# lo_âu
# cù
# sẩn
# ấn_loát
# thâm_thủng
# thấp_thỏm
# rịt
# rắn_đầu_rắn_mặt
# phê_chuẩn
# qui_lát
# ngẳng_nghiu
# chành
# menu
# nghịch_ngợm
# mẹ
# gà_gô
# xác_đáng
# đổ
# hoá_nhi
# lợi_quyền
# vong_hồn
# tuyệt_vời
# khiên_cưỡng
# số_vô_tỷ
# lều_khều
# đương_nhiệm
# dáng_vẻ
# giao_thiệp
# đoạt
# biên_giới
# quặt
# tâm_sự
# cổi
# kẻ_thù
# lủi
# khéo_mồm_khéo_miệng
# sột_soạt
# lần_khần
# sao_lãng
# vậy
# téo
# chi_tiết
# sờ
# băng
# bại_trận
# tranh_tối_tranh_sáng
# giáp_lá_cà
# núp_bóng
# tương_kỵ
# xấp
# vô_luận
# vô_hiệu
# du
# nhạt
# chiến_thắng
# doanh_gia
# cây_thân_cỏ
# cải_mả
# nhãi_nhép
# tắt
# sao_sa
# bướp
# trập_trùng
# dỗ_ngon_dỗ_ngọt
# kỳ
# quỷ_quyệt
# nhảy_cỡn
# có_lẽ
# dỗi
# bốc_trời
# bóng_nhoáng
# vật_chướng_ngại
# tất_thảy
# tuềnh_toàng
# toẻ
# quỹ_tiết_kiệm
# phúng_điếu
# kì_thú
# bóng_tối
# sao_nhãng
# rứt
# lóng_lánh
# phi_nghĩa
# hoàn_mỹ
# bì
# nhơ_nhuốc
# bắt_bồ
# miệt_mài
# phí
# lụt_lội
# chung_thuỷ
# xắt
# bình_toong
# dầy_dạn
# nhúm
# nhãi_ranh
# mép
# nhợt
# bạch_kim
# tê_thấp
# chứng_cứ
# ít
# nháy
# hết_dạ
# dập_dềnh
# tròng_trành
# vô_ngần
# thảo_hèn
# núi_băng
# báo_đền
# thẫn_thờ
# hồi_hương
# thận_trọng
# nhìn
# có_nghĩa
# tối_om
# đinh_ba
# củ_bình_vôi
# liến_láu
# rút_cục
# tòi
# lạnh_tanh
# qua_quýt
# đại_quân
# hết_sức
# nhẩy_vọt
# làm_đỏm
# phù_hợp
# quèo
# mài_dũa
# oai_quyền
# oang_oác
# cũ_rích
# xác_nhận
# kém_cỏi
# trời_ơi
# trôi_chảy
# động
# hoá
# dối
# may_mắn
# mắc
# thư_thả
# trắng_tinh
# toác_hoác
# xáo_trộn
# xước
# thời_kỳ
# sơ_sài
# thản_nhiên
# toàn
# vài_ba
# qua_loa
# nhảy_bổ
# tranh
# trong_lành
# nguồn_gốc
# đại_dương
# ngăn_cản
# cưới_xin
# nẫu_ruột_nẫu_gan
# thất_vọng
# núc
# thảnh_thơi
# xanh_xao
# ngông_nghênh
# thướt_tha
# giáp_vụ
# tôi
# êm_ấm
# dư
# kỳ_quan
# dơ_dáy
# chễm_chện
# kém
# cưỡi_đầu_cưỡi_cổ
# hiện
# cảnh_huống
# gau_gáu
# có_nghĩa
# xô
# từ_lấp_láy
# phòng_vệ
# bưng
# nhún_nhường
# công_nhân_quý_tộc
# dập_dìu
# phương_ngôn
# thẳng_tuột
# vô_ý_vô_tứ
# dự_trù
# chấm_phẩy
# tẳn_mẳn
# bỗng
# sơn_lam_chướng_khí
# ranh_ma
# vô_nghĩa
# tương_trợ
# thần_tình
# lo_âu
# mẹ
# rắn_mối
# trống_không
# ngất_ngưởng
# kiên_định
# dẻo_dai
# tuồng_như
# sờm_sỡ
# cáu_tiết
# hững_hờ
# rân
# thòi_lòi
# thối_hoăng
# sơ_sểnh
# trầy
# nô_giỡn
# ngành_ngọn
# tỷ_suất
# trả_thù
# nề_hà
# bromure_bạc
# ăn_quỵt
# khoèo
# tẽn
# trang_trọng
# đột_nhiên
# rưng_rức
# không_trách
# ưu_điểm
# bèo_tấm
# địa_phủ
# suyễn
# ghen_ghét
# tột_bậc
# thẩm
# chia_xẻ
# thẫn_thờ
# ăn_đậm
# lợi
# thoái_chí
# trêu_tức
# vỡ_hoang
# thư_ký_riêng
# đang
# hượm
# giang_sơn
# liễu
# thân_phụ
# phụ
# cơ_mà
# re
# rác_rến
# nhiếc_mắng
# ngó
# trộm_vía
# oi_bức
# vong_mạng
# rậm_rật
# tí_tị
# lễ_mễ
# lỏng
# trớn
# nương_tay
# gay_go
# biếng
# thúc_giục
# na_ná
# thùng_thình
# thử_hỏi
# nhồi
# xui_xẻo
# phơ_phất
# sinh_sự
# ngu_si
# man_trá
# xa_xôi
# giá_như
# tróc_nã
# thần_kì
# thần_kì
# tội_lỗi
# phải_chi
# tà_giáo
# vẩu
# kép
# ngọc_nữ
# xáp
# tệp_tin
# vô_phép
# dương_gian
# xệ
# lói
# tìm_kiếm
# hơi_hám
# sum_họp
# độc_giả
# bèo_tây
# ROM
# tuyển_thủ
# dối
# bù_loong
# chiếp
# tàn_nhang
# mới
# tiền_phong
# xem_mạch
# hết_thảy
# thoả_thích
# quầy_quả
# vụng_về
# giạng
# chầu_trời
# hụ
# ước_ao
# tẳn_mẳn
# văng_mạng
# thật_thà
# ma_tà
# từng
# tất_bật
# khỏ
# hôn_thú
# sùi
# tanh_tưởi
# khiếm_thị
# kiết_lỵ
# phong_toả
# me
# kỹ_lưỡng
# cáu_bẳn
# thu_hẹp
# rồi_đời
# làm_tới
# bề_bộn
# tợ_hồ
# tắt
# há
# toài
# phe_phái
# lý_lịch
# tê
# dạ
# kì_diệu
# choãi
# tô_giới
# do
# lắng_tai
# lem_nhem
# giấn
# chuệnh_choạc
# xuất_ngũ
# lụng_thụng
# tội_nhân
# quý_tướng
# cất_mộ
# ế
# toang_hoác
# hồi
# phún_nham
# thúc_giục
# lố
# không
# lủng_củng
# qua_loa
# gọn_ghẽ
# cá_tràu
# dằn_vặt
# thủ
# tỷ_lệ_nghịch
# đồng_loã
# mà_chược
# phản_trắc
# phồng
# nức_danh
# nõn_nường
# tâm_tưởng
# yên_lành
# uẩn_khúc
# thắc_thỏm
# om
# hư_hỏng
# đú_mỡ
# bồ_bịch
# trụt
# tràng_kỷ
# đi_chăng_nữa
# cải_cách_điền_địa
# mẹ
# xấp_xỉ
# yên_ấm
# cù_lao
# vênh_váo
# treo
# đỏ_hỏn
# quả_tình
# dạ_lí_hương
# biết_bao
# ngẫm_ngợi
# quên
# lính
# hối_hả
# dửng_dưng
# nghèo_nàn
# rầm
# ấm_cúng
# hồng
# khoái_cảm_thẩm_mỹ
# bêu_nhuốc
# trơ_tráo
# lẽ_ra
# lợi
# ùm
# rỉa_rói
# rửng_mỡ
# xoai_xoải
# phân_vô_cơ
# sang_nhượng
# khoáng_vật
# đụng
# tham_lam
# tùm_tũm
# chả
# vô_lương
# giờ_quốc_tế
# xiêu_vẹo
# tiếp_tục
# điểm_trang
# tiệm
# thiện
# hãm_tài
# dao_xây
# ối
# man_trá
# tọng
# tấm_tức
# chuyên_trị
# số_hữu_tỷ
# tuyệt_diệu
# nấp
# hèn
# dầu_con_hổ
# phị
# trả_thù
# bầm
# tỷ_số
# phụ_huynh
# ức_hiếp
# phục_thù
# gợn
# ơ_hay
# rốn
# toi
# rảnh_rỗi
# thần_tình
# vô_kỳ_hạn
# độ
# tụ_hợp
# thông_minh
# có_thai
# hiu_quạnh
# tẻ_ngắt
# ton_ton
# yếu
# nhấp_nháy
# mù_mịt
# vờ_vĩnh
# ưa_chuộng
# đờ
# mỹ_thuật_công_nghiệp
# nghỉ
# thể_hiện
# tù_đầy
# lãnh_đạm
# vô_công_rồi_nghề
# rầu
# háp
# sơ_sài
# kệ_nệ
# tha_ma
# cai_quản
# sao_đổi_ngôi
# xê_ri
# khinh_thường
# rậm_rì
# vẹn_tuyền
# toang
# bổ_ích
# dong_đao
# ta_thán
# cấp_thiết
# tránh
# nhạt_nhẽo
# khoanh_tay
# phê_duyệt
# tình_đầu
# suôn_sẻ
# hèn_đớn
# phục_thù
# mấp_mô
# rập_rình
# âm_ty
# tột_độ
# lộn_xộn
# khuy
# đầm_đầm
# máu_nóng
# tầm
# chung_qui_lại
# ứ
# ảo_tưởng
# phá_thối
# trọng_yếu
# biên_thuỳ
# quỉ_quyệt
# biệt_li
# vận_tốc
# hoan_nghinh
# đối_nghịch
# năn_nỉ
# đoạ_đầy
# gây_lộn
# lưỡng_lự
# bất_tiện
# ngang_dọc
# nhặng_xị
# quỹ
# trọc_lốc
# rầm_rì
# mua
# sục_sạo
# kiền
# khươi
# độc_địa
# sáng_suốt
# cố_quốc
# trễ_tràng
# vào_hùa
# khổ_một_nỗi
# nhúng
# lâm_thâm
# nhơ_bẩn
# thụ_động
# văn_thư
# hoa_giấy
# tổng_giám_đốc
# tróc
# rũ
# khen
# cổ_lỗ_sĩ
# quệt
# thắng
# từ_bỏ
# no_đủ
# quên_lửng
# cứng_quèo
# xe_lửa
# mệ
# khuất_tất
# ách_tắc
# cha
# y_sì
# lợn_dái
# lần_thần
# hèn_nhát
# giầy_xéo
# khít_khịt
# lộn_xộn
# khó
# bu
# nhút_nhát
# phải_cái_tội
# khấp_khểnh
# chấp_thuận
# truy_hoàn
# lưa_thưa
# nhóm
# xoay_xở
# trận
# bổ_ích
# sum_họp
# tía
# tóm_cổ
# thắng_lợi
# khiêm_tốn
# thụt
# lau_chau
# hình_nhi_thượng
# dọc
# trước_hết
# điểm_tô
# ganh_ghét
# lửa_binh
# đen_đủi
# sáng_ý
# dâu_bể
# neo_đơn
# đi_tiêu
# găngxtơ
# bán_sỉ
# lò_mò
# trùng
# thảnh_thơi
# ỏm_tỏi
# ngọn_nguồn
# nài_nỉ
# mở
# khó
# tên_hèm
# mộng_tưởng
# ống_phóng
# hủi
# vô_hạn
# tính_nết
# xăm_xắn
# chếch_mếch
# lĩnh
# huyết_tộc
# giải_vây
# buông_thõng
# lờ_lãi
# lo_âu
# tỷ_mỉ
# thưa_thớt
# nhất_nhất
# tột_đỉnh
# nhỏ_mọn
# chuyển_dịch
# hầu_phòng
# mở
# hùi_hụi
# sốc
# thu_nhặt
# phụ_bạc
# trở_quẻ
# phiêu_dạt
# ngưỡng_mộ
# quyến_luyến
# vô_vọng
# hắng_giọng
# mê_muội
# sóng_sượt
# vô_ích
# chậm
# thông_tõ
# tiến_đánh
# hiền_từ
# rỗi_rãi
# thanh_đạm
# nhá_nhem
# thẩy
# trùm
# khôn_xiết
# vấn_vít
# húi
# miệng_thế
# chém_đẹp
# chòng_ghẹo
# sum_họp
# tịch_thâu
# tra_hỏi
# tiến
# nhằng_nhịt
# nhơ_nhuốc
# hoặc
# khuông
# quyện
# mài_dũa
# ưu_tư
# ú_tim
# từ_giã
# dai_sức
# bơ
# dứt
# châm_chọc
# chậm
# bệnh_lý
# nè
# lùng_nhùng
# giam_cấm
# rốc
# lém
# túm
# lẩy_bẩy
# góp_nhặt
# choáng_choàng
# ước_hẹn
# nhịn_nhục
# ngay
# kính_cẩn
# ngang_bướng
# tri_kỷ
# dầu_lửa
# dẫn_chất
# đen_láy
# thứ_yếu
# trường
# giả_thiết
# chôn_cất
# trả_thù
# khuynh_diệp
# lâu
# tản_mát
# tàn_tệ
# sáng_nhoáng
# tàn_lụi
# u_tịch
# bán_hoa
# lấn
# thì_thầm
# gì
# đứt_quãng
# bình_chọn
# nhát
# lại_sức
# tông_tích
# có_lí
# tính_sổ
# tếch
# thiên_lý
# trợ_giúp
# áo_rét
# lơ
# cuộn
# nhợt
# tròn_bóng
# mau
# hốt_nhiên
# quần_áo
# nhẩy_nhót
# giao_kèo
# thảo_luận
# chiếu_tướng
# nhởn
# đẩn
# lưu_luyến
# ráo
# khổng_lồ
# rút
# dửng_tóc_gáy
# dàn_ý
# giấy_sáp
# nhơ_nhuốc
# đảm_trách
# hệ_thống_định_vị_toàn_cầu
# nhỏ_to
# lù_xù
# nhún
# quốc_đảo
# nhồi
# dầy_dặn
# tí_ti
# xá
# ít
# đích_đáng
# tinh_luyện
# từ_chối
# vững_bụng
# ủng_hộ
# giọi
# nịnh
# xui
# đi_đồng
# triết_lí
# si_mê
# bất_lương
# đề_phòng
# tăm_tối
# bồng
# ngả_nghiêng
# xen_kẽ
# giầu_sang
# trù_trừ
# thảo_dược
# hình_như
# cà_riềng_cà_tỏi
# chạy_đằng_trời
# xiềng_gông
# cảu_rảu
# lành
# nhất_loạt
# cằn_cặt
# hoa_nguyệt
# nghèo_đói
# nói_thánh_tướng
# man_trá
# chúi
# chổng_gọng
# lún
# thuộc_làu
# chích
# bụi_bờ
# quy_lát
# kinh_ngạc
# hữu_dụng
# trí_tuệ
# ngao_ngán
# ngoặc
# đầu_đề
# bản_lĩnh
# dính_líu
# mưu_cơ
# vô_số
# xử_lý
# phái
# thương_tổn
# ngất_ngưởng
# cõi_âm
# lý
# đảm_trách
# đốn
# chân_tay
# gương_sen
# sơ_sài
# hữu_định_luận
# tuyệt_vời
# lểu_đểu
# bàn_thảo
# ức_hiếp
# tiểu
# kiên_trung
# đếch
# đầy
# lờm_xờm
# chính_quy
# gánh_gồng
# lật_lọng
# neo_bấn
# cố_định
# tổng_đình_công
# hàm_ơn
# chích
# đĩ_bợm
# xuất_bản_phẩm
# cu
# súng_máy
# tân_ngữ
# liu_điu
# giá_như
# can_hệ
# láng_giềng
# liệt
# sổng
# đỗ_vũ
# ngộ
# mếch_lòng
# tùm
# cáo_biệt
# tương_đồng
# khô_ráo
# ốm_nhách
# tiệt
# cù_nhây
# nhãi_nhép
# thì_ra
# tù_tội
# ăn_trộm
# đàn_ông
# nhẹ_tênh
# bà_mụ
# săn
# khôn_cùng
# giảng_nghĩa
# dị_hình
# phao_đồn
# ế
# xấp_xỉ
# linh
# vắng_ngắt
# thật_thà
# hiền_từ
# kị_mã
# mấy_khi
# hướng_tâm
# vỗ
# cửa_quan
# vạch_trần
# tốn_phí
# má
# giữ_ý_giữ_tứ
# thay_đổi
# tỉnh_rụi
# nhạt
# má
# chầu_chẫu
# mướn
# thanh_la
# nhấm_nhẳn
# thực_tại_khách_quan
# tầy_trời
# ưng_ý
# ngật_ngưỡng
# nước_màu
# khuếch_đại
# hộp_tốc_độ
# nhúm
# lười_nhác
# má
# đừng
# lẻ_loi
# giầu_mạnh
# kỵ_thí
# viễn_tưởng
# đổ_vấy_đổ_vá
# hành_quân
# quầy_quậy
# phứt
# thi_cử
# vắng
# ngao_ngán
# rợ
# thưa
# hồ_đồ
# biếu
# cứt
# vượt
# tù_tội
# lo_âu
# chân_phương
# đơn
# thuộc_hạ
# nhấp
# kính_mát
# vật_lý_trị_liệu
# lẽ_ra
# lờn_bơn
# trần_gian
# thuyết_đa_nguyên
# ép_nài
# ô_nhục
# thủ_thỉ
# phải_chi
# nhem_nhẻm
# mê_mệt
# mờ_ám
# điền_trang
# mặt_đường
# buộc
# xuềnh_xòng
# vô_lý
# bọ_đa
# hạ_thủ
# lỏng
# hồ_ly_tinh
# cố_ý
# hiếp_đáp
# tuột
# hiền_hậu
# bận_bịu
# nguyên_vẹn
# trường_đấu
# me
# giả_bộ
# dạ_lí_hương
# tự_tín
# làu_nhàu
# thề_thốt
# chuẩn_mực
# gian_xảo
# ái_tình
# khơi
# kính_trọng
# trơ_khấc
# chung_quy
# gấp
# vui
# tản_bộ
# vô_ngần
# lộn_lạo
# ô_dù
# hối_thúc
# cáo_thoái
# tanh_banh
# mềm
# hốt_nhiên
# có_nhân
# thanh_tao
# vũ_khí_vi_trùng
# vắng_ngắt
# nghêu
# phóng_khoáng
# kiêu_hùng
# nhà_giam
# quy_phạm
# đồng_đẳng
# đại_nạn
# hải_mã
# đôi_chút
# đóng
# xe_điện_ngầm
# đa_tư_đa_lự
# nghèo
# méo_mó
# chơi_xấu
# nguyên_do
# sờn_lòng
# uy_hiếp
# ngả_nghiêng
# mở_màn
# sử_thi
# ê
# mắc_cỡ
# chăm_chăm
# cây_thân_thảo
# cô
# tập_trung
# mạnh
# kém_cỏi
# quốc_gia
# lều_phều
# phới
# lý_sự
# cải_táng
# toán_loạn
# tột_độ
# định_lý
# quái_quỷ
# giết_hại
# xanh_xao
# tròn_trĩnh
# đùa_cợt
# góp_nhóp
# ắt_hẳn
# lạt
# vị_tha
# liếm_láp
# miễn_nhiệm
# yên_nghỉ
# phong_bế
# tươi
# khăn_áo
# kì_dị
# bán_sỉ
# trời_đất
# nghịch
# dầy_dạn
# tệ_nạn
# ngậu_xị
# xăm
# cữ
# phải_tội
# tỳ_bà
# nghĩa_trang
# cải_cách
# cá_thia_thia
# quỷ_cái
# mặc_dù
# mặn_mòi
# lui
# cục_súc
# xé_rào
# dùng_dắng
# tầm_tầm
# chìm
# vút
# thảm
# ngoại_tình
# cạm
# lẻn
# rười_rượi
# tấm
# lạu_bạu
# câu_kéo
# tịt
# không_mấy_khi
# xô
# tớ
# giao_ước
# lưu_không
# nức_nở
# túng_thiếu
# ong_vẽ
# lợi_danh
# nghễnh_ngãng
# quên_lãng
# thất_bại
# khẳng_khái
# tập_hợp
# sơ_sài
# góc_cạnh
# chiểu
# rứa
# mùng_tơi
# bạc_mầu
# tắt
# chớp_chới
# phân_trần
# tỷ_lệ_bản_đồ
# khốn_cùng
# méo_mó
# sơ_sài
# vượt_bực
# đoá
# mồ
# phản_đối
# ì_ầm
# thờn_bơn
# tai_vạ
# cô_nhi_viện
# mạt_kì
# dôi_thừa
# trút
# vì_sao
# tiễn
# hối_lỗi
# trầm_ngâm
# mềm_mỏng
# xẩm
# trít
# lạy_van
# sầu_oán
# nồng_nặc
# cây
# hoả_thiêu
# nhiễu_sự
# ngọc_nữ
# nản_lòng
# vinh
# dự_án
# quy_chế
# nghỉ
# mua_sỉ
# xiêu_lòng
# phương_pháp
# bổ_dụng
# kỵ
# chua_ngoét
# tranh_thuỷ_mặc
# chổng_kềnh
# hồ_nghi
# tiết
# khúng_khắng
# to_đùng
# rộng
# ve_sầu
# xuống
# xọp
# tra_khảo
# lần_khần
# dời_đổi
# tràn_lan
# hốt_nhiên
# vị_tha
# vạch_trần
# cứng_lưỡi
# mới_tinh
# nhắn_nhe
# cánh
# rón
# nghiêng_ngả
# vận_tải
# cầu_tàu
# nền_nếp
# lộn_phèo
# thâm_nhập
# thư_nhàn
# trừ_diệt
# thảm_kịch
# bóng_lộn
# khẩn_hoang
# hỗ_trợ
# no_ấm
# lựa_chọn
# phí_tổn
# trời_đất
# khập_khễnh
# dài_ngoằng_ngoẵng
# tằn_tiện
# quỉ_quyệt
# tha_thứ
# xuất_phát_điểm
# lấm_láp
# thẳng_tay
# loạng_choạng
# thoái_chí
# rỉa_rói
# đớn_hèn
# chêm
# cá_cóc
# rỗng_không
# xâm_chiếm
# loa
# sum_họp
# phong_phú
# nũng_nịu
# dịp
# ngóng_trông
# hụm
# tóc_xanh
# đền_rồng
# dây_thun
# cấm_quân
# thành_phố
# vòng_quanh
# vũ_đoán
# cù_ngoéo
# xử_lý_từ_xa
# ý_thức
# lớp
# tắc_nghẽn
# ham
# phí
# nhắm_mắt_xuôi_tay
# muộn_mằn
# tăng
# lối
# Phật_giáo
# tính_mạng
# dùng_dằng
# thả_giàn
# trách
# vô_kỷ_luật
# thu_hút
# hùm
# ngả
# hiếu_chủ
# ướt_sượt
# kiên_trì
# vỉa_hè
# thật_thà
# tối_mò
# mẩy
# quyết_nghị
# choen_hoẻn
# tuyệt
# chơ_chỏng
# toác
# thuyết_phiếm_thần
# giong
# di_dịch
# lính_tráng
# bềnh_bồng
# cóp_nhặt
# vẹo_vọ
# nói_bóng_nói_gió
# má
# u_ám
# kế_cận
# mê_mải
# thông_hiểu
# dầu_nhờn
# phiêu_dạt
# hoàn_cảnh
# ba_rọi
# giữ
# dày
# chuệnh_choạng
# nhử
# dính
# kiêng_kị
# da_đồi_mồi
# ton_hót
# pha_phôi
# đồn_đãi
# thuyết_nhất_nguyên
# ưu_tư
# hỗn_xược
# tàn_tích
# ỉa
# phô_bầy
# cuộn
# ti
# tha_thẩn
# cò_mồi
# tha_thẩn
# liệu_thần_hồn
# rập_rờn
# tôm_rồng
# chây_lười
# thương_xót
# phong_bế
# cắp_củm
# bom_khinh_khí
# quý_báu
# phớt_lờ
# nhanh
# hắng_giọng
# ra
# nắc_nỏm
# xe_pháo
# sự_vụ_chủ_nghĩa
# đường_sá
# thúc_đẩy
# phần_nhiều
# tâng_hẩng
# công_khai
# hết_nhẽ
# vu_oan_giá_hoạ
# bội_nghĩa
# gầy
# cấn_cá
# ly_tán
# lủng_củng
# tí
# xóm_làng
# học_trò
# tư_thông
# cộc_cằn
# kì_diệu
# ngả_vạ
# mới_toanh
# củ_mỡ
# thưa_thớt
# bất_hiếu
# la_hét
# kinh_qua
# xuống
# thiếu_thốn
# yêu_cầu
# nhận
# len_lỏi
# uy_phong
# quát_tháo
# ngồi_chồm_hỗm
# mềm_dẻo
# nhích
# can_đảm
# vô_ngần
# nguyên_cớ
# quý_vị
# nhão_nhoẹt
# hết_sức
# liên_quan
# vùng
# châu
# đơn
# biểu_lộ
# lẩn_tránh
# tròn_xoe
# từ_thực
# khóm
# vọc
# búng_báng
# mỏng
# trẻ_ranh
# rảnh_rỗi
# miễn_thứ
# bồ_kết
# thúc_đẩy
# quý_trọng
# rên_rỉ
# bất_giác
# công_lênh
# suy_bì
# lang_bang
# ngượng_ngùng
# ruộng_rẫy
# sạch
# vẩy
# hôm_mai
# dệ
# nam_mô
# vỏn_vẹn
# đốn
# sức_ép
# vắng_vẻ
# tuyệt_diệu
# láo_lếu
# mới_mẻ
# chấp_nhận
# ục_ịch
# mua
# nhảm_nhí
# áng_chừng
# hươ
# cao_thượng
# diện_mạo
# một_thể
# rình
# ưu_điểm
# tai_quái
# loa_kèn
# nằm_mê
# trôi_chảy
# cuối_cùng
# tuyến_giáp_trạng
# bội_tình
# kĩ_nữ
# rộng_lượng
# ỉa
# bác
# xâm_lăng
# tóp_tép
# cửa_ải
# mau
# nghề_nghiệp
# nản_lòng
# từ_chối
# kỹ
# bằng_vai
# bạng_nhạng
# chợt
# thi_hài
# tràn_ngập
# tuốt_luốt
# huyết_quản
# nhát
# lầu_nhầu
# hoài
# cố
# phó_thác
# mỏng_manh
# cung_đao
# sử_dụng
# thờ_phụng
# nhân_tiện
# mặn_mà
# giòn
# rỗi_rãi
# hữu_dụng
# huyền_hoặc
# phe
# vốn_dĩ
# ròng_rã
# may_ra
# dầy_cộp
# tốt
# ruột_nghé
# đếch
# súp_lơ
# lù_xù
# khôn
# hoà_hợp
# ngu_đần
# mô_tả
# đồng_ruộng
# siêu_tập_ngữ_liệu
# thật_lực
# phối_chế
# vô_bổ
# thử_nghiệm
# gái_điếm
# cỗi_cằn
# bình_tĩnh
# nhất_định
# khí_khái
# phơi_phóng
# sốt_dẻo
# hoan_hỉ
# rầm
# bềnh_bồng
# tổng_thư_ký
# hoang_phí
# sự_thế
# nhà_cầu
# ối
# thắc_thỏm
# bỏ_xừ
# ít_ra
# phi_lí
# ngại_ngần
# môn_đệ
# đệm
# thủ_thành
# mỏm
# thang_máy
# hùn
# ri_vê
# phá_ngang
# lộn_tùng_phèo
# cứng
# thành_phố
# đầu_đề
# thấu_triệt
# nhủi
# oa_oa
# phượng
# xom
# trang_nghiêm
# mềm_nhũn
# tới_tấp
# mu
# khuất_tất
# ranh_ma
# tảo
# mới_cứng
# nức_danh
# cõi_tục
# trau_chuốt
# thuộc_lòng
# lợt
# bộc_trực
# khát
# so_bì
# ơn_đức
# lúc
# thóp
# tức_thị
# tuyệt
# vì
# nhạt_thếch
# lò_vi_ba
# đi_đại_tiện
# sở_thích
# tàn_nhẫn
# hoa_mõm_sói
# dứt_khoát
# tiết_kiệm
# từ_kiêng_kỵ
# tầy_đình
# nhận_thực
# dũng
# tuyệt_diệu
# khôn_xiết
# thâm_hiểm
# thi_hành
# lăn_quay
# chõ_mồm
# lét
# tượt
# cốt_yếu
# hấp_hem
# thối_hôn
# tuyệt
# giáng
# ứng_dụng
# phạm_pháp
# vung_vảy
# tị
# miên_man
# nhất_quyết
# mà_lại
# sơn_hà
# đắng_cay
# ngả_nghiêng
# Kitô_giáo
# sẫm
# thoạt_tiên
# gầy_guộc
# can_đảm
# nghĩ_ngợi
# ẩm_ướt
# hứa_hươu_hứa_vượn
# tâm_lý
# kiên_định
# hoi
# dập_dềnh
# lêu_têu
# khởi_đầu
# khó
# vu_vạ
# quán
# dương_gian
# phớt
# thần_diệu
# lo_lắng
# hệ_miễn_nhiễm
# nhầy_nhụa
# sang_nhượng
# hoạ
# ký_hiệu
# ngơ_ngẩn
# thưa
# tha_thiết
# hưng_thịnh
# hợp_lí
# kì_cọ
# lộp_độp
# quách
# tùng_xẻo
# đích_thực
# thạo
# dầu_dãi
# sơ_sài
# vai_vế
# mối_lái
# ưu_điểm
# thuyết_tiền_định
# chủn
# độ
# tập_hợp
# củi_rả
# hiền
# vườn_trẻ
# cầm_cố
# cõi_âm
# xem
# thoả_thuê
# cửa_thiền
# phứa
# nghìn_trùng
# nguyệt_hoa
# giãi_tỏ
# khác
# nín_nhịn
# chất_nổ
# lỡ_thời
# hát_tuồng
# nhân_cách
# ga_men
# nhập_nhoạng
# đè_đầu_cưỡi_cổ
# xịt
# buồn_tẻ
# trạnh
# khoa_học_kỹ_thuật
# báo_ơn
# chạm_ngõ
# chuồng_tiêu
# mồng
# rướn
# giò
# nghĩa_lý_Or_nghĩa_lí
# thây_kệ
# mai_sau
# lỏng_lẻo
# quẩy
# dở_dang
# rởm
# dấu_chấm_hỏi
# ấp_ủ
# nuốt_tươi
# xơ_cua
# giày_xéo
# đạo_nghĩa
# tu_sửa
# lềnh_phềnh
# me
# bỡn
# quái_gở
# rối_rắm
# huýt_gió
# nan
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\Things\PyProject\Word-Similarity\src\fasttext.ipynb Cell 16' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/d%3A/Things/PyProject/Word-Similarity/src/fasttext.ipynb#ch0000015?line=2'>3</a> for i in train_vec2:
#       <a href='vscode-notebook-cell:/d%3A/Things/PyProject/Word-Similarity/src/fasttext.ipynb#ch0000015?line=3'>4</a>     print(i)
# ----> <a href='vscode-notebook-cell:/d%3A/Things/PyProject/Word-Similarity/src/fasttext.ipynb#ch0000015?line=4'>5</a>     ft.get_word_vector(i)
#
# File c:\Users\nguye\AppData\Local\Programs\Python\Python38\lib\site-packages\fasttext\FastText.py:124, in _FastText.get_word_vector(self, word)
#     <a href='file:///c%3A/Users/nguye/AppData/Local/Programs/Python/Python38/lib/site-packages/fasttext/FastText.py?line=121'>122</a> dim = self.get_dimension()
#     <a href='file:///c%3A/Users/nguye/AppData/Local/Programs/Python/Python38/lib/site-packages/fasttext/FastText.py?line=122'>123</a> b = fasttext.Vector(dim)
# --> <a href='file:///c%3A/Users/nguye/AppData/Local/Programs/Python/Python38/lib/site-packages/fasttext/FastText.py?line=123'>124</a> self.f.getWordVector(b, word)
#     <a href='file:///c%3A/Users/nguye/AppData/Local/Programs/Python/Python38/lib/site-packages/fasttext/FastText.py?line=124'>125</a> return np.array(b)
#
# TypeError: getWordVector(): incompatible function arguments. The following argument types are supported:
#     1. (self: fasttext_pybind.fasttext, arg0: fasttext_pybind.Vector, arg1: str) -> None
#
# Invoked with: <fasttext_pybind.fasttext object at 0x0000021C7DC03630>, <fasttext_pybind.Vector object at 0x0000021E51B7EAF0>, nan

# %%
y_train = enc.fit_transform(train_dataset['Relation'].values.reshape(-1,1))

x_test = np.array([i for i in train_dataset.apply(flatten, axis=1)])
y_test = enc.fit_transform(train_dataset['Relation'].values.reshape(-1,1))

# %%
ft.get_word_vector(['cõi_âm', 'cõi_tục'])
